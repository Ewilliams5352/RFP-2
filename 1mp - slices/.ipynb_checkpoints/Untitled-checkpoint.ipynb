# %%
import pandas as pd
import json
from sklearn.cluster import MiniBatchKMeans
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import MeanShift
from sklearn.cluster import AgglomerativeClustering

# %%
df1 = pd.read_json('albums_0-999.json')
df2 = pd.read_json('artists_0-999.json')
df3 = pd.read_json('songs_0-999.json')
df1 = df1.transpose()
df2 = df2.transpose()
df3 = df3.transpose()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19261 entries, 6vV5UrXcfyQD1wu4Qo2I9K to 7D6Y19tjm4DQNch39FeWpO
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   album_type              18478 non-null  object
#  1   artists                 18478 non-null  object
#  2   available_markets       18478 non-null  object
#  3   copyrights              18478 non-null  object
#  4   external_ids            18478 non-null  object
#  5   external_urls           18478 non-null  object
#  6   genres                  18478 non-null  object
#  7   href                    18478 non-null  object
#  8   id                      18478 non-null  object
#  9   images                  18478 non-null  object
#  10  label                   18469 non-null  object
#  11  name                    18478 non-null  object
#  12  popularity              18478 non-null  object
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9723 entries, 2wIVse2owClT7go1WT98tk to 77bNdkKYBBmc30CisCA6tE
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   external_urls  9723 non-null   object
#  1   followers      9723 non-null   object
#  2   genres         9723 non-null   object
#  3   href           9723 non-null   object
#  4   id             9723 non-null   object
#  5   images         9723 non-null   object
#  6   name           9723 non-null   object
#  7   popularity     9723 non-null   object
#  8   type           9723 non-null   object
#  9   uri            9723 non-null   object
# dtypes: object(10)
# memory usage: 1.1+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 34441 entries, 0UaMYEvWZi0ZqiDOoHU3YI to 5RVuBrXVLptAEbGJdSDzL5
# Data columns (total 17 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   album              34441 non-null  object
#  1   artists            34441 non-null  object
#  2   available_markets  34441 non-null  object
#  3   disc_number        34441 non-null  object
#  4   duration_ms        34441 non-null  object
#  5   explicit           34441 non-null  object
#  6   external_ids       34441 non-null  object
#  7   external_urls      34441 non-null  object
#  8   href               34441 non-null  object
#  9   id                 34441 non-null  object
#  10  is_local           34441 non-null  object
#  11  name               34441 non-null  object
#  12  popularity         34441 non-null  object
#  13  preview_url        15459 non-null  object
#  14  track_number       34441 non-null  object
# ...

# %%
# Assuming df is your dataframe
selected_features = ['popularity', 'duration_ms']  # Selecting relevant numerical features
X = df3[selected_features].values

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply Mini Batch K Means
n_clusters = 3  # Number of clusters
kmeans = MiniBatchKMeans(n_clusters=n_clusters, random_state=42)
clusters = kmeans.fit_predict(X_scaled)

# Add cluster labels to the dataframe
df3['cluster'] = clusters

# Analyze the clusters
cluster_centers = scaler.inverse_transform(kmeans.cluster_centers_)  # Inverse transform to get original scale
cluster_sizes = pd.Series(clusters).value_counts().sort_index()

print("Cluster Centers:")
print(pd.DataFrame(cluster_centers, columns=selected_features))
print("\nCluster Sizes:")
print(cluster_sizes)
# Out:
# Cluster Centers:
#    popularity    duration_ms
# 0   51.108481  225156.182155
# 1    4.902456  218455.507503
# 2   20.378272  413074.637435
#
# Cluster Sizes:
# 0    15772
# 1    16122
# 2     2547
# dtype: int64
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\cluster\_kmeans.py:1043: UserWarning: MiniBatchKMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can prevent it by setting batch_size >= 5120 or by setting the environment variable OMP_NUM_THREADS=4
#   warnings.warn(

# %%
"""


# Assuming df is your dataframe
selected_features = ['popularity', 'duration_ms']  # Selecting relevant numerical features
X = df[selected_features].values

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply Mean Shift
bandwidth = 0.8  # Bandwidth parameter
meanshift = MeanShift(bandwidth=bandwidth)
clusters = meanshift.fit_predict(X_scaled)

# Add cluster labels to the dataframe
df['cluster'] = clusters

# Analyze the clusters
cluster_centers = scaler.inverse_transform(meanshift.cluster_centers_)  # Inverse transform to get original scale
cluster_sizes = pd.Series(clusters).value_counts().sort_index()

print("Cluster Centers:")
print(pd.DataFrame(cluster_centers, columns=selected_features))
print("\nCluster Sizes:")
print(cluster_sizes)
"""
# Out:
# '\n\n\n# Assuming df is your dataframe\nselected_features = [\'popularity\', \'duration_ms\']  # Selecting relevant numerical features\nX = df[selected_features].values\n\n# Normalize the data\nscaler = StandardScaler()\nX_scaled = scaler.fit_transform(X)\n\n# Apply Mean Shift\nbandwidth = 0.8  # Bandwidth parameter\nmeanshift = MeanShift(bandwidth=bandwidth)\nclusters = meanshift.fit_predict(X_scaled)\n\n# Add cluster labels to the dataframe\ndf[\'cluster\'] = clusters\n\n# Analyze the clusters\ncluster_centers = scaler.inverse_transform(meanshift.cluster_centers_)  # Inverse transform to get original scale\ncluster_sizes = pd.Series(clusters).value_counts().sort_index()\n\nprint("Cluster Centers:")\nprint(pd.DataFrame(cluster_centers, columns=selected_features))\nprint("\nCluster Sizes:")\nprint(cluster_sizes)\n'

# %%
# Assuming df is your dataframe
selected_features = ['popularity', 'duration_ms']  # Selecting relevant numerical features
X = df3[selected_features].values

# Normalize the data
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Apply Agglomerative Clustering
n_clusters = 3  # Number of clusters
agglomerative = AgglomerativeClustering(n_clusters=n_clusters)
clusters = agglomerative.fit_predict(X_scaled)

# Add cluster labels to the dataframe
df3['cluster'] = clusters

# Analyze the clusters
cluster_sizes = pd.Series(clusters).value_counts().sort_index()

print("\nCluster Sizes:")
print(cluster_sizes)
# Out:
# Cluster Sizes:
# 0    19241
# 1     3567
# 2    11633
# dtype: int64

# %%
df2.head()
# Out:
#                                                             external_urls  \
# 2wIVse2owClT7go1WT98tk  {'spotify': 'https://open.spotify.com/artist/2...
# 26dSoYclwsYLMAKD3tpOr4  {'spotify': 'https://open.spotify.com/artist/2...
# 6vWDO969PvNqNYHIOW5v0m  {'spotify': 'https://open.spotify.com/artist/6...
# 31TPClRtHm23RisEBtV3X7  {'spotify': 'https://open.spotify.com/artist/3...
# 5EvFsr3kj42KNv97ZEnqij  {'spotify': 'https://open.spotify.com/artist/5...
#
#                                                 followers  \
# 2wIVse2owClT7go1WT98tk   {'href': None, 'total': 2386591}
# 26dSoYclwsYLMAKD3tpOr4  {'href': None, 'total': 13836642}
# 6vWDO969PvNqNYHIOW5v0m  {'href': None, 'total': 36504075}
# 31TPClRtHm23RisEBtV3X7  {'href': None, 'total': 13667356}
# 5EvFsr3kj42KNv97ZEnqij   {'href': None, 'total': 2099287}
#
#                                                                    genres  \
# 2wIVse2owClT7go1WT98tk  [dance pop, hip hop, hip pop, neo soul, pop ra...
# ...

# %%
columns_to_drop = ['external_urls', 'href', 'id', 'images', 'uri']  # List of columns to drop

# Drop columns
df2.drop(columns=columns_to_drop, inplace=True)

# %%
df2.head()
# Out:
#                                                 followers  \
# 2wIVse2owClT7go1WT98tk   {'href': None, 'total': 2386591}
# 26dSoYclwsYLMAKD3tpOr4  {'href': None, 'total': 13836642}
# 6vWDO969PvNqNYHIOW5v0m  {'href': None, 'total': 36504075}
# 31TPClRtHm23RisEBtV3X7  {'href': None, 'total': 13667356}
# 5EvFsr3kj42KNv97ZEnqij   {'href': None, 'total': 2099287}
#
#                                                                    genres  \
# 2wIVse2owClT7go1WT98tk  [dance pop, hip hop, hip pop, neo soul, pop ra...
# 26dSoYclwsYLMAKD3tpOr4                                   [dance pop, pop]
# 6vWDO969PvNqNYHIOW5v0m                                         [pop, r&b]
# 31TPClRtHm23RisEBtV3X7                                   [dance pop, pop]
# 5EvFsr3kj42KNv97ZEnqij                           [pop rap, reggae fusion]
#
#                                      name popularity    type
# 2wIVse2owClT7go1WT98tk      Missy Elliott         70  artist
# ...

# %%
df2.head(25)
# Out:
#                                                 followers  \
# 2wIVse2owClT7go1WT98tk   {'href': None, 'total': 2386591}
# 26dSoYclwsYLMAKD3tpOr4  {'href': None, 'total': 13836642}
# 6vWDO969PvNqNYHIOW5v0m  {'href': None, 'total': 36504075}
# 31TPClRtHm23RisEBtV3X7  {'href': None, 'total': 13667356}
# 5EvFsr3kj42KNv97ZEnqij   {'href': None, 'total': 2099287}
# 23zg3TcAtWQy7J6upgbUnj  {'href': None, 'total': 10974183}
# 6wPhSqRtPu1UhRCDX5yaDJ   {'href': None, 'total': 5502730}
# 1Y8cdNmUJH7yBTd9yOvr5i   {'href': None, 'total': 6932798}
# 1G9G7WwrXka3Z1r7aIDjI7   {'href': None, 'total': 2518660}
# 2jw70GZXlAI8QzWeY2bgRc   {'href': None, 'total': 3717288}
# 2Hjj68yyUPiC0HKEOigcEp    {'href': None, 'total': 990733}
# 27FGXRNruFoOdf1vP8dqcH   {'href': None, 'total': 1536747}
# 0f5nVCcR06GX8Qikz0COtT   {'href': None, 'total': 2820235}
# 0p4nmQO2msCgU4IF37Wi3j  {'href': None, 'total': 10574655}
# 7bXgB6jMjp9ATFy66eO08Z  {'href': None, 'total': 20955897}
# ...

# %%
for i in range(len(df2["name"])):
    if '' in df2["name"][i]:
        print(df2[i])

# %%
df2.head(395)
# Out:
#                                                 followers  \
# 2wIVse2owClT7go1WT98tk   {'href': None, 'total': 2386591}
# 26dSoYclwsYLMAKD3tpOr4  {'href': None, 'total': 13836642}
# 6vWDO969PvNqNYHIOW5v0m  {'href': None, 'total': 36504075}
# 31TPClRtHm23RisEBtV3X7  {'href': None, 'total': 13667356}
# 5EvFsr3kj42KNv97ZEnqij   {'href': None, 'total': 2099287}
# ...                                                   ...
# 28INUgyzTTRbvSphrJbgZ2    {'href': None, 'total': 523087}
# 3NPpFNZtSTHheNBaWC82rB   {'href': None, 'total': 2960365}
# 5CE2IfdYZEQGIDsfiRm8SI    {'href': None, 'total': 601308}
# 1hwAhXzyuEUjug2pyNVSvg     {'href': None, 'total': 61735}
# 2CIMQHirSU0MQqyYHq0eOx   {'href': None, 'total': 2732613}
#
#                                                                    genres  \
# 2wIVse2owClT7go1WT98tk  [dance pop, hip hop, hip pop, neo soul, pop ra...
# 26dSoYclwsYLMAKD3tpOr4                                   [dance pop, pop]
# ...
